# %% [markdown]
# # ESM 267: Bannister Assignment 3
#
# Map goal: To identify regions of the Santa Barbara and Goleta urban areas that are hotter than the rest of the community (i.e. with a high heat severity index).
#
# Add Urban Heat layer from the Trust for Public Land to the map from Arc LivingAtlas.
#
# Specify the id of the layer:

# %%
layer_1_id = "4f6d72903c9741a6a6ee6349f5393572"

# %% [markdown]
# Specify the ArcGIS Online service we want to connect to, and the client ID we'll authenticate with. (See https://developers.arcgis.com/python/guide/working-with-different-authentication-schemes/#User-authentication-with-OAuth-2.0 for instructions on how to set `my_App_ID`.)

# %%
my_server = "https://ucsb.maps.arcgis.com" # this is the UCSB institutional ArcGIS Online server
my_App_ID = "iOl1kn1BOZUtrCXx"

# %% [markdown]
# Import GIS module:

# %%
from arcgis.gis import GIS

# %% [markdown]
# Create a GIS instance on the ArcGIS Online server. (This will invoke any necessary authentication dialogues. Don't worry if you get an `Unverified HTTPS request` error message.)

# %%
my_gis = GIS(my_server, client_id = my_App_ID)
# Out:
# Please sign in to your GIS and paste the code that is obtained below.
# If a web browser does not automatically open, please navigate to the URL below yourself instead.
# Opening web browser to navigate to: https://ucsb.maps.arcgis.com/sharing/rest//oauth2/authorize?response_type=code&client_id=iOl1kn1BOZUtrCXx&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&state=GofpeDz9pwg7Woi7mTkvAeBocMbWSd
# Enter code obtained on signing in using SAML:  ············································································································································································································································
# ...

# %% [markdown]
# Generate a map.

# %%
my_map = my_gis.map(location = 'Santa Barbara, CA')
my_map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-f24b0886-db27-4996-a642-963cae2629f6"><img src=""></img></div>
# <div class="map-html-embed-preview-f24b0886-db27-4996-a642-963cae2629f6"></div>

# %% [markdown]
# # <center>Urban Heat Islands</center>
# <center>(aka places that need some trees)</center>

# %% [markdown]
# Create layer and link to layer id from above.

# %%
layer_1 = my_gis.content.get(layer_1_id)
layer_1
# Out:
# <Item title:"Urban heat islands for U.S. cities" type:Imagery Layer owner:TPL_GIS_Support>

# %% [markdown]
# Add layer to map.

# %%
my_map.add_layer(layer_1)
